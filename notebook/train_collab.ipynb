# %%
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 5 (delta 2), reused 5 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 3.86 KiB | 987.00 KiB/s, done.
# From https://github.com/hackrudra1234/transformer-translation
#    47941bf..e172540  main       -> origin/main
# Updating 47941bf..e172540
# Fast-forward
#  main_train.py               | 426 +++++++++++++++++++++++++-------------------
#  notebook/train_collab.ipynb | 425 ++++++++++++++-----------------------------
#  2 files changed, 377 insertions(+), 474 deletions(-)

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !python main_train.py
# Out:
# Traceback (most recent call last):
#   File "/content/transformer-translation/main_train.py", line 14, in <module>
#     from config import (
#     ...<20 lines>...
#     )
# ImportError: cannot import name 'BLEU_MAX_EXAMPLES' from 'config' (/content/transformer-translation/config.py)

# %%
import pandas as pd

results_path = (
    "/content/drive/MyDrive/"
    "transformer-translation/experiments/"
    "results.csv"
)

results = pd.read_csv(results_path)

results
# Out:
#                              experiment  d_model  num_heads  d_ff  \
# 0  d128_h4_enc3_dec3_ff512_bs32_lr0.001      128          4   512
#
#    encoder_layers  decoder_layers  dropout  learning_rate  batch_size  \
# 0               3               3      0.1          0.001          32
#
#    best_epoch  best_val_loss  best_perplexity  greedy_bleu  beam_bleu  \
# 0          10       3.922425        50.522839          NaN        NaN
#
#    total_time_min                                    checkpoint_path
# 0       11.706865  /content/drive/MyDrive/transformer-translation...
