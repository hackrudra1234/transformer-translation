# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/hackrudra1234/transformer-translation.git
# Out:
# fatal: destination path 'transformer-translation' already exists and is not an empty directory.

# %%
# %cd transformer-translation
# Out:
# /content/transformer-translation

# %%
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 283 bytes | 283.00 KiB/s, done.
# From https://github.com/hackrudra1234/transformer-translation
#    0710eab..c2349e1  main       -> origin/main
# Updating 0710eab..c2349e1
# Fast-forward
#  config.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %pip install -q datasets sacrebleu tqdm pandas matplotlib sentencepiece

# %%
# !git log -1 --oneline
# Out:
# 732b6f0 (HEAD -> main, origin/main, origin/HEAD) BPE

# %%
# !python main_train.py
# Out:
# ======================================================================
# DEVICE INFORMATION
# ======================================================================
# Device: cuda
# GPU: NVIDIA L4
# GPU Memory: 22.03 GB
#
# ======================================================================
# EXPERIMENT
# ======================================================================
# Experiment name: bpe16k_d128_h8_enc4_dec4_ff512_bs32_lr0.00075initdefaultschedconstanttieFalseb10.9_b20.98_eps1e-09
# Checkpoint path: /content/drive/MyDrive/transformer-translation/checkpoints/bpe16k_d128_h8_enc4_dec4_ff512_bs32_lr0.00075initdefaultschedconstanttieFalseb10.9_b20.98_eps1e-09.pt
# Experiment directory: /content/drive/MyDrive/transformer-translation/experiments
# Plot directory: /content/drive/MyDrive/transformer-translation/plots
#
# ======================================================================
# LOADING DATASET
# ======================================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Total examples: 51467
# Training examples: 46320
# Validation examples: 5147
#
# ======================================================================
# BUILDING VOCABULARY
# ======================================================================
# BPE vocabulary size: 16000
# Training batches: 1448
# Validation batches: 161
#
# ======================================================================
# CREATING TRANSFORMER
# ======================================================================
# Total parameters: 8,005,248
# Trainable parameters: 8,005,248
#
# ======================================================================
# MODEL CONFIGURATION
# ======================================================================
# D_MODEL: 128
# NUM_HEADS: 8
# D_FF: 512
# ENCODER LAYERS: 4
# DECODER LAYERS: 4
# DROPOUT: 0.1
# BATCH SIZE: 32
# INITIALIZATION: default
# LR SCHEDULE: constant
# WARMUP STEPS: 0
# LEARNING RATE: 0.00075
# EPOCHS: 20
# LABEL SMOOTHING: 0.0
# WEIGHT TYING: False
# ADAM BETA1: 0.9
# ADAM BETA2: 0.98
# ADAM EPS: 1e-09
# BLEU MAX EXAMPLES: 100
# BEAM SIZE: 4
# LENGTH PENALTY: 0.6
#
# ======================================================================
# STARTING TRAINING
# ======================================================================

# %%
import pandas as pd

results_path = (
    "/content/drive/MyDrive/"
    "transformer-translation/experiments/"
    "results_v6.csv"
)

results = pd.read_csv(results_path)

results
# Out:
#                                           experiment  d_model  num_heads  \
# 0  d128_h8_enc4_dec4_ff512_bs32_lr0.00075initdefa...      128          8
# 1  d128_h8_enc4_dec4_ff512_bs32_lr0.00075initdefa...      128          8
# 2  d128_h8_enc4_dec4_ff512_bs32_lr0.00075initdefa...      128          8
# 3  d128_h8_enc4_dec4_ff512_bs32_lr0.00075initdefa...      128          8
#
#    d_ff  encoder_layers  decoder_layers  dropout  learning_rate  batch_size  \
# 0   512               4               4      0.1        0.00075          32
# 1   512               4               4      0.1        0.00075          32
# 2   512               4               4      0.1        0.00075          32
# 3   512               4               4      0.1        0.00075          32
#
#   initialization  ...  adam_beta1 adam_beta2      adam_eps  best_epoch  \
# 0        default  ...         0.9       0.98  1.000000e-09          10
# 1        default  ...         0.9       0.98  1.000000e-09          10
# 2        default  ...         0.9       0.98  1.000000e-09          15
# 3        default  ...         0.9       0.98  1.000000e-09          20
#
#    best_val_loss  best_perplexity  greedy_bleu  beam_bleu  total_time_min  \
# 0       3.896207        49.215432     2.562220   2.174971       10.638961
# 1       3.896207        49.215432     2.562220   2.174971       10.734003
# 2       3.828999        46.016435     3.615409   3.335243       14.637575
# 3       3.802914        44.831638     3.702471   3.009385       19.707705
#
#                                      checkpoint_path
# 0  /content/drive/MyDrive/transformer-translation...
# 1  /content/drive/MyDrive/transformer-translation...
# 2  /content/drive/MyDrive/transformer-translation...
# 3  /content/drive/MyDrive/transformer-translation...
#
# [4 rows x 24 columns]

# %%
import pandas as pd

history = pd.read_csv( "/content/drive/MyDrive/transformer-translation/experiments/d128_h8_enc4_dec4_ff512_bs32_lr0.001initxavier_history.csv"
)

history
# Out:
#    epoch  train_loss  val_loss   perplexity  epoch_time_min
# 0      1    6.237672  7.057453  1161.482848        1.553419
# 1      2    6.130836  7.488578  1787.508547        1.553361
# 2      3    6.104022  7.343563  1546.211663        1.556469
# 3      4    6.092220  7.583595  1965.682979        1.552653
# 4      5    6.078740  7.802510  2446.735223        1.556901
# 5      6    6.070748  8.199196  3638.022978        1.558929
# 6      7    6.067168  8.348537  4223.997005        1.563685
# 7      8    6.043494  8.592169  5389.288673        1.561409
# 8      9    6.011452  8.161287  3502.692072        1.546956
# 9     10    6.005712  8.182855  3579.059663        1.561419
