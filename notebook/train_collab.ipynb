# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/hackrudra1234/transformer-translation.git
# Out:
# Cloning into 'transformer-translation'...
# remote: Enumerating objects: 94, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 94 (delta 33), reused 78 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (94/94), 235.12 KiB | 1.23 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
# %cd transformer-translation
# Out:
# /content/transformer-translation

# %%
# !git pull
# Out:
# Already up to date.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %pip install -q datasets sacrebleu tqdm pandas matplotlib
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.6/129.6 kB 14.3 MB/s eta 0:00:00

# %%
# !git log -1 --oneline
# Out:
# 3e25ee3 (HEAD -> main, origin/main, origin/HEAD) Adding bleu config

# %%
# !python main_train.py
# Out:
# ======================================================================
# DEVICE INFORMATION
# ======================================================================
# Device: cuda
# GPU: Tesla T4
# GPU Memory: 14.56 GB
#
# ======================================================================
# EXPERIMENT
# ======================================================================
# Experiment name: d256_h8_enc4_dec4_ff1024_bs32_lr0.001
# Checkpoint path: /content/drive/MyDrive/transformer-translation/checkpoints/d256_h8_enc4_dec4_ff1024_bs32_lr0.001.pt
# Experiment directory: /content/drive/MyDrive/transformer-translation/experiments
# Plot directory: /content/drive/MyDrive/transformer-translation/plots
#
# ======================================================================
# LOADING DATASET
# ======================================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md: 100% 28.1k/28.1k [00:00<00:00, 52.1MB/s]
#
# de-en/train-00000-of-00001.parquet: downloading bytes:  49% 4.32M/8.80M [00:00<00:00, 4.64MB/s]
# de-en/train-00000-of-00001.parquet: downloading bytes: 100% 8.59M/8.59M [00:00<00:00, 8.76MB/s,  841kB/s  ]
# de-en/train-00000-of-00001.parquet: reconstructing file: 100% 8.80M/8.80M [00:00<00:00, 8.97MB/s,  863kB/s  ]
# Generating train split: 100% 51467/51467 [00:00<00:00, 494983.50 examples/s]
# Total examples: 51467
# Training examples: 46320
# Validation examples: 5147
#
# ======================================================================
# BUILDING VOCABULARY
# ======================================================================
# German vocab: 26953
# English vocab: 17627
# Training batches: 1448
# Validation batches: 161
#
# ======================================================================
# CREATING TRANSFORMER
# ======================================================================
# Total parameters: 23,303,131
# Trainable parameters: 23,303,131
#
# ======================================================================
# MODEL CONFIGURATION
# ======================================================================
# D_MODEL: 256
# NUM_HEADS: 8
# D_FF: 1024
# ENCODER LAYERS: 4
# DECODER LAYERS: 4
# DROPOUT: 0.1
# BATCH SIZE: 32
# LEARNING RATE: 0.001
# EPOCHS: 10
# BLEU MAX EXAMPLES: 100
# BEAM SIZE: 4
# LENGTH PENALTY: 0.6
#
# ======================================================================
# STARTING TRAINING
# ======================================================================
# Epoch 01/10 | Train Loss: 5.0435 | Val Loss: 4.6260 | PPL: 102.10 | Time: 2.47 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d256_h8_enc4_dec4_ff1024_bs32_lr0.001.pt
# Traceback (most recent call last):
#   File "/content/transformer-translation/main_train.py", line 963, in <module>
#     main()
#     ~~~~^^
#   File "/content/transformer-translation/main_train.py", line 461, in main
#     train_loss = train_one_epoch(
#         model=model,
#     ...<3 lines>...
#         device=device
#     )
#   File "/content/transformer-translation/training/train.py", line 87, in train_one_epoch
#     total_loss += loss.item()
#                   ~~~~~~~~~^^
# KeyboardInterrupt
# ^C

# %%
import pandas as pd

results_path = (
    "/content/drive/MyDrive/"
    "transformer-translation/experiments/"
    "results_v2.csv"
)

results = pd.read_csv(results_path)

results
# Out:
#                               experiment  d_model  num_heads  d_ff  \
# 0   d128_h4_enc3_dec3_ff512_bs32_lr0.001      128          4   512
# 1   d128_h4_enc3_dec3_ff512_bs32_lr0.001      128          4   512
# 2   d128_h8_enc3_dec3_ff512_bs32_lr0.001      128          8   512
# 3   d128_h8_enc4_dec4_ff512_bs32_lr0.001      128          8   512
# 4   d256_h8_enc4_dec4_ff512_bs32_lr0.001      256          8   512
# 5  d256_h8_enc4_dec4_ff1024_bs32_lr0.001      256          8  1024
#
#    encoder_layers  decoder_layers  dropout  learning_rate  batch_size  \
# 0               3               3      0.1          0.001          32
# 1               3               3      0.1          0.001          32
# 2               3               3      0.1          0.001          32
# 3               4               4      0.1          0.001          32
# 4               4               4      0.1          0.001          32
# 5               4               4      0.1          0.001          32
#
#    best_epoch  best_val_loss  best_perplexity  greedy_bleu  beam_bleu  \
# 0          10       3.922425        50.522839          NaN        NaN
# 1          10       3.922425        50.522839     2.550098   2.785348
# 2          10       3.914647        50.131387     2.935859   2.997479
# 3          10       3.876671        48.263265     2.559888   3.269426
# 4           7       3.908329        49.815653     1.498817   2.309811
# 5           4       4.316354        74.914981     0.413989   0.411121
#
#    total_time_min                                    checkpoint_path
# 0       11.706865  /content/drive/MyDrive/transformer-translation...
# 1       12.039635  /content/drive/MyDrive/transformer-translation...
# 2       12.961591  /content/drive/MyDrive/transformer-translation...
# 3       15.724867  /content/drive/MyDrive/transformer-translation...
# 4       23.021986  /content/drive/MyDrive/transformer-translation...
# 5       25.555602  /content/drive/MyDrive/transformer-translation...
