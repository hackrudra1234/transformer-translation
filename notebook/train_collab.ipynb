# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/hackrudra1234/transformer-translation.git
# Out:
# Cloning into 'transformer-translation'...
# remote: Enumerating objects: 94, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 94 (delta 33), reused 78 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (94/94), 235.12 KiB | 1.23 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
# %cd transformer-translation
# Out:
# /content/transformer-translation

# %%
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 307 bytes | 307.00 KiB/s, done.
# From https://github.com/hackrudra1234/transformer-translation
#    43b33c1..69e2444  main       -> origin/main
# Updating 43b33c1..69e2444
# Fast-forward
#  config.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %pip install -q datasets sacrebleu tqdm pandas matplotlib
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.6/129.6 kB 14.3 MB/s eta 0:00:00

# %%
# !git log -1 --oneline
# Out:
# 3e25ee3 (HEAD -> main, origin/main, origin/HEAD) Adding bleu config

# %%
# !python main_train.py
# Out:
# ======================================================================
# DEVICE INFORMATION
# ======================================================================
# Device: cuda
# GPU: Tesla T4
# GPU Memory: 14.56 GB
#
# ======================================================================
# EXPERIMENT
# ======================================================================
# Experiment name: d128_h8_enc4_dec4_ff512_bs32_lr0.001initxavierschedtransformer
# Checkpoint path: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h8_enc4_dec4_ff512_bs32_lr0.001initxavierschedtransformer.pt
# Experiment directory: /content/drive/MyDrive/transformer-translation/experiments
# Plot directory: /content/drive/MyDrive/transformer-translation/plots
#
# ======================================================================
# LOADING DATASET
# ======================================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Total examples: 51467
# Training examples: 46320
# Validation examples: 5147
#
# ======================================================================
# BUILDING VOCABULARY
# ======================================================================
# German vocab: 26953
# English vocab: 17627
# Training batches: 1448
# Validation batches: 161
#
# ======================================================================
# CREATING TRANSFORMER
# ======================================================================
# Total parameters: 9,825,371
# Trainable parameters: 9,825,371
#
# ======================================================================
# MODEL CONFIGURATION
# ======================================================================
# D_MODEL: 128
# NUM_HEADS: 8
# D_FF: 512
# ENCODER LAYERS: 4
# DECODER LAYERS: 4
# DROPOUT: 0.1
# BATCH SIZE: 32
# INITIALIZATION: xavier
# LR SCHEDULE: transformer
# WARMUP STEPS: 4000
# LEARNING RATE: 0.001
# EPOCHS: 10
# LABEL SMOOTHING: 0.1
# BLEU MAX EXAMPLES: 100
# BEAM SIZE: 4
# LENGTH PENALTY: 0.6
#
# ======================================================================
# STARTING TRAINING
# ======================================================================
# Epoch 01/10 | Train Loss: 6.8268 | Val Loss: 5.6453 | PPL: 282.96 | LR: 0.000506 | Time: 1.53 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h8_enc4_dec4_ff512_bs32_lr0.001initxavierschedtransformer.pt
# Epoch 02/10 | Train Loss: 5.5201 | Val Loss: 5.2909 | PPL: 198.52 | LR: 0.001012 | Time: 1.60 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h8_enc4_dec4_ff512_bs32_lr0.001initxavierschedtransformer.pt
# Epoch 03/10 | Train Loss: 5.2712 | Val Loss: 5.1321 | PPL: 169.38 | LR: 0.001341 | Time: 1.62 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h8_enc4_dec4_ff512_bs32_lr0.001initxavierschedtransformer.pt
# Epoch 04/10 | Train Loss: 5.0852 | Val Loss: 5.0149 | PPL: 150.64 | LR: 0.001161 | Time: 1.62 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h8_enc4_dec4_ff512_bs32_lr0.001initxavierschedtransformer.pt
# Epoch 05/10 | Train Loss: 4.9370 | Val Loss: 4.9538 | PPL: 141.72 | LR: 0.001039 | Time: 1.63 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h8_enc4_dec4_ff512_bs32_lr0.001initxavierschedtransformer.pt
# Epoch 06/10 | Train Loss: 4.8296 | Val Loss: 4.9178 | PPL: 136.71 | LR: 0.000948 | Time: 1.62 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h8_enc4_dec4_ff512_bs32_lr0.001initxavierschedtransformer.pt
# Epoch 07/10 | Train Loss: 4.7448 | Val Loss: 4.9035 | PPL: 134.76 | LR: 0.000878 | Time: 1.63 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h8_enc4_dec4_ff512_bs32_lr0.001initxavierschedtransformer.pt
# Epoch 08/10 | Train Loss: 4.6724 | Val Loss: 4.8852 | PPL: 132.32 | LR: 0.000821 | Time: 1.62 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h8_enc4_dec4_ff512_bs32_lr0.001initxavierschedtransformer.pt
# Epoch 09/10 | Train Loss: 4.6131 | Val Loss: 4.8847 | PPL: 132.25 | LR: 0.000774 | Time: 1.61 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h8_enc4_dec4_ff512_bs32_lr0.001initxavierschedtransformer.pt
# Epoch 10/10 | Train Loss: 4.5592 | Val Loss: 4.8930 | PPL: 133.35 | LR: 0.000735 | Time: 1.61 min
#
# ======================================================================
# LOADING BEST MODEL
# ======================================================================
# Loaded best model from epoch: 9
#
# ======================================================================
# GREEDY BLEU
# ======================================================================
# Greedy BLEU: 1.37
# Greedy BLEU time: 0.29 min
#
# ======================================================================
# BEAM BLEU
# ======================================================================
# Beam BLEU: 2.18
# Beam BLEU time: 1.18 min
#
# ======================================================================
# GENERATING PLOTS
# ======================================================================
#
# ======================================================================
# EXPERIMENT COMPLETE
# ======================================================================
# Experiment: d128_h8_enc4_dec4_ff512_bs32_lr0.001initxavierschedtransformer
# Best epoch: 9
# Best validation loss: 4.8847
# Best perplexity: 132.25
# Greedy BLEU: 1.37
# Beam BLEU: 2.18
# Training time: 16.16 minutes
# Greedy BLEU time: 0.29 minutes
# Beam BLEU time: 1.18 minutes
# Peak GPU memory: 8.03 GB
#
# Checkpoint:
# /content/drive/MyDrive/transformer-translation/checkpoints/d128_h8_enc4_dec4_ff512_bs32_lr0.001initxavierschedtransformer.pt
#
# History:
# /content/drive/MyDrive/transformer-translation/experiments/d128_h8_enc4_dec4_ff512_bs32_lr0.001initxavierschedtransformer_history.csv
#
# Results:
# /content/drive/MyDrive/transformer-translation/experiments/results_v2.csv
#
# Loss plot:
# /content/drive/MyDrive/transformer-translation/plots/d128_h8_enc4_dec4_ff512_bs32_lr0.001initxavierschedtransformer_loss.png
#
# Perplexity plot:
# /content/drive/MyDrive/transformer-translation/plots/d128_h8_enc4_dec4_ff512_bs32_lr0.001initxavierschedtransformer_perplexity.png
#
# Epoch-time plot:
# /content/drive/MyDrive/transformer-translation/plots/d128_h8_enc4_dec4_ff512_bs32_lr0.001initxavierschedtransformer_time.png

# %%
import pandas as pd

results_path = (
    "/content/drive/MyDrive/"
    "transformer-translation/experiments/"
    "results_v2.csv"
)

results = pd.read_csv(results_path)

results
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_919/1179460404.py in <cell line: 0>()
#       7 )
#       8
# ----> 9 results = pd.read_csv(results_path)
#      10
#      11 results
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     624
#     625     with parser:
# --> 626         return parser.read(nrows)
#     627
#     628
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1921                     columns,
#    1922                     col_dict,
# -> 1923                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1924                     nrows
#    1925                 )
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     232         try:
#     233             if self.low_memory:
# --> 234                 chunks = self._reader.read_low_memory(nrows)
#     235                 # destructive to chunks
#     236                 data = _concatenate_chunks(chunks)
#
# parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 17 fields in line 4, saw 20

# %%
import pandas as pd

history = pd.read_csv( "/content/drive/MyDrive/transformer-translation/experiments/d128_h8_enc4_dec4_ff512_bs32_lr0.001initxavier_history.csv"
)

history
# Out:
#    epoch  train_loss  val_loss   perplexity  epoch_time_min
# 0      1    6.237672  7.057453  1161.482848        1.553419
# 1      2    6.130836  7.488578  1787.508547        1.553361
# 2      3    6.104022  7.343563  1546.211663        1.556469
# 3      4    6.092220  7.583595  1965.682979        1.552653
# 4      5    6.078740  7.802510  2446.735223        1.556901
# 5      6    6.070748  8.199196  3638.022978        1.558929
# 6      7    6.067168  8.348537  4223.997005        1.563685
# 7      8    6.043494  8.592169  5389.288673        1.561409
# 8      9    6.011452  8.161287  3502.692072        1.546956
# 9     10    6.005712  8.182855  3579.059663        1.561419
