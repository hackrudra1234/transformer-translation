# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/hackrudra1234/transformer-translation.git
# Out:
# Cloning into 'transformer-translation'...
# remote: Enumerating objects: 149, done.
# remote: Counting objects: 100% (149/149), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 149 (delta 68), reused 113 (delta 32), pack-reused 0 (from 0)
# Receiving objects: 100% (149/149), 248.51 KiB | 1.39 MiB/s, done.
# Resolving deltas: 100% (68/68), done.

# %%
# %cd transformer-translation
# Out:
# /content/transformer-translation

# %%
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 301 bytes | 301.00 KiB/s, done.
# From https://github.com/hackrudra1234/transformer-translation
#    c9ba186..88f8bb3  main       -> origin/main
# Updating c9ba186..88f8bb3
# Fast-forward
#  config.py | 4 ++--
#  1 file changed, 2 insertions(+), 2 deletions(-)

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %pip install -q datasets sacrebleu tqdm pandas matplotlib
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.6/129.6 kB 15.5 MB/s eta 0:00:00

# %%
# !git log -1 --oneline
# Out:
# 3e25ee3 (HEAD -> main, origin/main, origin/HEAD) Adding bleu config

# %%
# !python main_train.py
# Out:
# ======================================================================
# DEVICE INFORMATION
# ======================================================================
# Device: cuda
# GPU: Tesla T4
# GPU Memory: 14.56 GB
#
# ======================================================================
# EXPERIMENT
# ======================================================================
# Experiment name: d128_h8_enc4_dec4_ff512_bs64_lr0.001initdefaultschedconstant
# Checkpoint path: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h8_enc4_dec4_ff512_bs64_lr0.001initdefaultschedconstant.pt
# Experiment directory: /content/drive/MyDrive/transformer-translation/experiments
# Plot directory: /content/drive/MyDrive/transformer-translation/plots
#
# ======================================================================
# LOADING DATASET
# ======================================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Total examples: 51467
# Training examples: 46320
# Validation examples: 5147
#
# ======================================================================
# BUILDING VOCABULARY
# ======================================================================
# German vocab: 26953
# English vocab: 17627
# Training batches: 724
# Validation batches: 81
#
# ======================================================================
# CREATING TRANSFORMER
# ======================================================================
# Total parameters: 9,825,371
# Trainable parameters: 9,825,371
#
# ======================================================================
# MODEL CONFIGURATION
# ======================================================================
# D_MODEL: 128
# NUM_HEADS: 8
# D_FF: 512
# ENCODER LAYERS: 4
# DECODER LAYERS: 4
# DROPOUT: 0.1
# BATCH SIZE: 64
# INITIALIZATION: default
# LR SCHEDULE: constant
# WARMUP STEPS: 0
# LEARNING RATE: 0.001
# EPOCHS: 10
# LABEL SMOOTHING: 0.0
# BLEU MAX EXAMPLES: 100
# BEAM SIZE: 4
# LENGTH PENALTY: 0.6
#
# ======================================================================
# STARTING TRAINING
# ======================================================================
# Traceback (most recent call last):
#   File "/content/transformer-translation/main_train.py", line 1036, in <module>
#     main()
#     ~~~~^^
#   File "/content/transformer-translation/main_train.py", line 528, in main
#     train_loss = train_one_epoch(
#         model=model,
#     ...<4 lines>...
#         scheduler=scheduler
#     )
#   File "/content/transformer-translation/training/train.py", line 79, in train_one_epoch
#     loss.backward()
#     ~~~~~~~~~~~~~^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/_tensor.py", line 631, in backward
#     torch.autograd.backward(
#     ~~~~~~~~~~~~~~~~~~~~~~~^
#         self, gradient, retain_graph, create_graph, inputs=inputs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/usr/local/lib/python3.13/dist-packages/torch/autograd/__init__.py", line 381, in backward
#     _engine_run_backward(
#     ~~~~~~~~~~~~~~~~~~~~^
#         tensors,
#         ^^^^^^^^
#     ...<5 lines>...
#         accumulate_grad=True,
#         ^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/usr/local/lib/python3.13/dist-packages/torch/autograd/graph.py", line 869, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         t_outputs, *args, **kwargs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )  # Calls into the C++ engine to run the backward pass
#     ^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 1.98 GiB. GPU 0 has a total capacity of 14.56 GiB of which 11.81 MiB is free. Including non-PyTorch memory, this process has 14.55 GiB memory in use. Of the allocated memory 12.78 GiB is allocated by PyTorch, and 1.64 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)

# %%
import pandas as pd

results_path = (
    "/content/drive/MyDrive/"
    "transformer-translation/experiments/"
    "results_v3.csv"
)

results = pd.read_csv(results_path)

results
# Out:
#                                           experiment  d_model  num_heads  \
# 0  d128_h8_enc4_dec4_ff512_bs32_lr0.001initdefaul...      128          8
# 1  d128_h8_enc4_dec4_ff512_bs32_lr0.001initdefaul...      128          8
# 2  d128_h8_enc4_dec4_ff512_bs32_lr0.001initdefaul...      128          8
#
#    d_ff  encoder_layers  decoder_layers  dropout  learning_rate  batch_size  \
# 0   512               4               4     0.10          0.001          32
# 1   512               4               4     0.20          0.001          32
# 2   512               4               4     0.05          0.001          32
#
#   initialization lr_schedule  warmup_steps  label_smoothing  best_epoch  \
# 0        default    constant             0              0.1          10
# 1        default    constant             0              0.0          10
# 2        default    constant             0              0.0           7
#
#    best_val_loss  best_perplexity  greedy_bleu  beam_bleu  total_time_min  \
# 0       4.677673       107.519550     3.065280   2.753836       16.140430
# 1       3.969281        52.946429     2.252962   2.205115       15.627775
# 2       3.864388        47.674069     2.345692   2.789912       15.556011
#
#                                      checkpoint_path
# 0  /content/drive/MyDrive/transformer-translation...
# 1  /content/drive/MyDrive/transformer-translation...
# 2  /content/drive/MyDrive/transformer-translation...

# %%
import pandas as pd

history = pd.read_csv( "/content/drive/MyDrive/transformer-translation/experiments/d128_h8_enc4_dec4_ff512_bs32_lr0.001initxavier_history.csv"
)

history
# Out:
#    epoch  train_loss  val_loss   perplexity  epoch_time_min
# 0      1    6.237672  7.057453  1161.482848        1.553419
# 1      2    6.130836  7.488578  1787.508547        1.553361
# 2      3    6.104022  7.343563  1546.211663        1.556469
# 3      4    6.092220  7.583595  1965.682979        1.552653
# 4      5    6.078740  7.802510  2446.735223        1.556901
# 5      6    6.070748  8.199196  3638.022978        1.558929
# 6      7    6.067168  8.348537  4223.997005        1.563685
# 7      8    6.043494  8.592169  5389.288673        1.561409
# 8      9    6.011452  8.161287  3502.692072        1.546956
# 9     10    6.005712  8.182855  3579.059663        1.561419
