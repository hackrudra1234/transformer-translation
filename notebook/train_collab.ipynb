# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/hackrudra1234/transformer-translation.git
# Out:
# Cloning into 'transformer-translation'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 74 (delta 21), reused 66 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (74/74), 228.90 KiB | 1.67 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
# %cd transformer-translation
# Out:
# /content/transformer-translation

# %%
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 3), reused 5 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 791 bytes | 395.00 KiB/s, done.
# From https://github.com/hackrudra1234/transformer-translation
#    2c3813b..bbf4e39  main       -> origin/main
# Updating 2c3813b..bbf4e39
# Fast-forward
#  config.py                   |   2 +-
#  notebook/train_collab.ipynb | 121 ++++++++++----------------------------------
#  2 files changed, 29 insertions(+), 94 deletions(-)

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %pip install -q datasets sacrebleu tqdm pandas matplotlib
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.6/129.6 kB 15.5 MB/s eta 0:00:00

# %%
# !git log -1 --oneline
# Out:
# 3e25ee3 (HEAD -> main, origin/main, origin/HEAD) Adding bleu config

# %%
# !python main_train.py
# Out:
# ======================================================================
# DEVICE INFORMATION
# ======================================================================
# Device: cuda
# GPU: Tesla T4
# GPU Memory: 14.56 GB
#
# ======================================================================
# EXPERIMENT
# ======================================================================
# Experiment name: d256_h8_enc4_dec4_ff512_bs32_lr0.001
# Checkpoint path: /content/drive/MyDrive/transformer-translation/checkpoints/d256_h8_enc4_dec4_ff512_bs32_lr0.001.pt
# Experiment directory: /content/drive/MyDrive/transformer-translation/experiments
# Plot directory: /content/drive/MyDrive/transformer-translation/plots
#
# ======================================================================
# LOADING DATASET
# ======================================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Total examples: 51467
# Training examples: 46320
# Validation examples: 5147
#
# ======================================================================
# BUILDING VOCABULARY
# ======================================================================
# German vocab: 26953
# English vocab: 17627
# Training batches: 1448
# Validation batches: 161
#
# ======================================================================
# CREATING TRANSFORMER
# ======================================================================
# Total parameters: 21,201,883
# Trainable parameters: 21,201,883
#
# ======================================================================
# MODEL CONFIGURATION
# ======================================================================
# D_MODEL: 256
# NUM_HEADS: 8
# D_FF: 512
# ENCODER LAYERS: 4
# DECODER LAYERS: 4
# DROPOUT: 0.1
# BATCH SIZE: 32
# LEARNING RATE: 0.001
# EPOCHS: 10
# BLEU MAX EXAMPLES: 100
# BEAM SIZE: 4
# LENGTH PENALTY: 0.6
#
# ======================================================================
# STARTING TRAINING
# ======================================================================
# Epoch 01/10 | Train Loss: 4.9613 | Val Loss: 4.4788 | PPL: 88.13 | Time: 2.25 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d256_h8_enc4_dec4_ff512_bs32_lr0.001.pt
# Epoch 02/10 | Train Loss: 4.3497 | Val Loss: 4.2162 | PPL: 67.78 | Time: 2.30 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d256_h8_enc4_dec4_ff512_bs32_lr0.001.pt
# Epoch 03/10 | Train Loss: 4.0590 | Val Loss: 4.0678 | PPL: 58.43 | Time: 2.32 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d256_h8_enc4_dec4_ff512_bs32_lr0.001.pt
# Epoch 04/10 | Train Loss: 3.8443 | Val Loss: 3.9939 | PPL: 54.26 | Time: 2.30 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d256_h8_enc4_dec4_ff512_bs32_lr0.001.pt
# Epoch 05/10 | Train Loss: 3.6711 | Val Loss: 3.9440 | PPL: 51.62 | Time: 2.29 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d256_h8_enc4_dec4_ff512_bs32_lr0.001.pt
# Epoch 06/10 | Train Loss: 3.5222 | Val Loss: 3.9183 | PPL: 50.31 | Time: 2.30 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d256_h8_enc4_dec4_ff512_bs32_lr0.001.pt
# Epoch 07/10 | Train Loss: 3.3917 | Val Loss: 3.9083 | PPL: 49.82 | Time: 2.30 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d256_h8_enc4_dec4_ff512_bs32_lr0.001.pt
# Epoch 08/10 | Train Loss: 3.2770 | Val Loss: 3.9121 | PPL: 50.01 | Time: 2.29 min
# Epoch 09/10 | Train Loss: 3.1790 | Val Loss: 3.9214 | PPL: 50.47 | Time: 2.28 min
# Epoch 10/10 | Train Loss: 3.0884 | Val Loss: 3.9149 | PPL: 50.14 | Time: 2.27 min
#
# ======================================================================
# LOADING BEST MODEL
# ======================================================================
# Loaded best model from epoch: 7
#
# ======================================================================
# GREEDY BLEU
# ======================================================================
# Greedy BLEU: 1.50
# Greedy BLEU time: 0.27 min
#
# ======================================================================
# BEAM BLEU
# ======================================================================
# Beam BLEU: 2.31
# Beam BLEU time: 1.15 min
#
# ======================================================================
# GENERATING PLOTS
# ======================================================================
#
# ======================================================================
# EXPERIMENT COMPLETE
# ======================================================================
# Experiment: d256_h8_enc4_dec4_ff512_bs32_lr0.001
# Best epoch: 7
# Best validation loss: 3.9083
# Best perplexity: 49.82
# Greedy BLEU: 1.5
# Beam BLEU: 2.31
# Training time: 23.02 minutes
# Greedy BLEU time: 0.27 minutes
# Beam BLEU time: 1.15 minutes
# Peak GPU memory: 8.86 GB
#
# Checkpoint:
# /content/drive/MyDrive/transformer-translation/checkpoints/d256_h8_enc4_dec4_ff512_bs32_lr0.001.pt
#
# History:
# /content/drive/MyDrive/transformer-translation/experiments/d256_h8_enc4_dec4_ff512_bs32_lr0.001_history.csv
#
# Results:
# /content/drive/MyDrive/transformer-translation/experiments/results.csv
#
# Loss plot:
# /content/drive/MyDrive/transformer-translation/plots/d256_h8_enc4_dec4_ff512_bs32_lr0.001_loss.png
#
# Perplexity plot:
# /content/drive/MyDrive/transformer-translation/plots/d256_h8_enc4_dec4_ff512_bs32_lr0.001_perplexity.png
#
# Epoch-time plot:
# /content/drive/MyDrive/transformer-translation/plots/d256_h8_enc4_dec4_ff512_bs32_lr0.001_time.png

# %%
import pandas as pd

results_path = (
    "/content/drive/MyDrive/"
    "transformer-translation/experiments/"
    "results.csv"
)

results = pd.read_csv(results_path)

results
# Out:
#                              experiment  d_model  num_heads  d_ff  \
# 0  d128_h4_enc3_dec3_ff512_bs32_lr0.001      128          4   512
# 1  d128_h4_enc3_dec3_ff512_bs32_lr0.001      128          4   512
# 2  d128_h8_enc3_dec3_ff512_bs32_lr0.001      128          8   512
# 3  d128_h8_enc4_dec4_ff512_bs32_lr0.001      128          8   512
# 4  d256_h8_enc4_dec4_ff512_bs32_lr0.001      256          8   512
#
#    encoder_layers  decoder_layers  dropout  learning_rate  batch_size  \
# 0               3               3      0.1          0.001          32
# 1               3               3      0.1          0.001          32
# 2               3               3      0.1          0.001          32
# 3               4               4      0.1          0.001          32
# 4               4               4      0.1          0.001          32
#
#    best_epoch  best_val_loss  best_perplexity  greedy_bleu  beam_bleu  \
# 0          10       3.922425        50.522839          NaN        NaN
# 1          10       3.922425        50.522839     2.550098   2.785348
# 2          10       3.914647        50.131387     2.935859   2.997479
# 3          10       3.876671        48.263265     2.559888   3.269426
# 4           7       3.908329        49.815653     1.498817   2.309811
#
#    total_time_min                                    checkpoint_path
# 0       11.706865  /content/drive/MyDrive/transformer-translation...
# 1       12.039635  /content/drive/MyDrive/transformer-translation...
# 2       12.961591  /content/drive/MyDrive/transformer-translation...
# 3       15.724867  /content/drive/MyDrive/transformer-translation...
# 4       23.021986  /content/drive/MyDrive/transformer-translation...
