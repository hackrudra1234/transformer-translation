# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/hackrudra1234/transformer-translation.git
# Out:
# Cloning into 'transformer-translation'...
# remote: Enumerating objects: 234, done.
# remote: Counting objects: 100% (234/234), done.
# remote: Compressing objects: 100% (154/154), done.
# remote: Total 234 (delta 125), reused 169 (delta 60), pack-reused 0 (from 0)
# Receiving objects: 100% (234/234), 266.21 KiB | 24.20 MiB/s, done.
# Resolving deltas: 100% (125/125), done.

# %%
# %cd transformer-translation
# Out:
# /content/transformer-translation

# %%
# !git pull
# Out:
# Already up to date.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %pip install -q datasets sacrebleu tqdm pandas matplotlib sentencepiece
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.6/129.6 kB 15.7 MB/s eta 0:00:00

# %%
# !git log -1 --oneline
# Out:
# 1b3ef75 (HEAD -> main, origin/main, origin/HEAD) os issue

# %%
# !python main_train.py
# Out:
# ...
# DEVICE INFORMATION
# ...
# Device: cuda
# GPU: NVIDIA A100-SXM4-40GB
# GPU Memory: 39.49 GB
#
# ...
# EXPERIMENT
# ...
# Experiment name: bpe8000_d128_h8_enc4_dec4_ff512_bs32_lr0.00075initdefaultschedconstanttieFalseb10.9_b20.98_eps1e-09
# Checkpoint path: /content/drive/MyDrive/transformer-translation/checkpoints/bpe8000_d128_h8_enc4_dec4_ff512_bs32_lr0.00075initdefaultschedconstanttieFalseb10.9_b20.98_eps1e-09.pt
# Experiment directory: /content/drive/MyDrive/transformer-translation/experiments
# Plot directory: /content/drive/MyDrive/transformer-translation/plots
#
# ...
# LOADING DATASET
# ...
# README.md: 100% 28.1k/28.1k [00:00<00:00, 57.1MB/s]
#
# de-en/train-00000-of-00001.parquet: downloading bytes:  94% 8.24M/8.80M [00:01<00:00, 5.68MB/s,  405kB/s  ]
# de-en/train-00000-of-00001.parquet: downloading bytes: 100% 8.59M/8.59M [00:01<00:00, 4.99MB/s,  824kB/s  ]
# de-en/train-00000-of-00001.parquet: reconstructing file: 100% 8.80M/8.80M [00:01<00:00, 5.11MB/s,  847kB/s  ]
# ...

# %%
import pandas as pd

results_path = (
    "/content/drive/MyDrive/"
    "transformer-translation/experiments/"
    "results_v6.csv"
)

results = pd.read_csv(results_path)

results
# Out:
#                                           experiment  d_model  num_heads  \
# 0  bpe16k_d128_h8_enc4_dec4_ff512_bs32_lr0.00075i...      128          8
# 1  bpe8000_d128_h8_enc4_dec4_ff512_bs32_lr0.00075...      128          8
#
#    d_ff  encoder_layers  decoder_layers  dropout  learning_rate  batch_size  \
# 0   512               4               4      0.1        0.00075          32
# 1   512               4               4      0.1        0.00075          32
#
#   initialization  ...  adam_beta1 adam_beta2      adam_eps  best_epoch  \
# 0        default  ...         0.9       0.98  1.000000e-09          20
# 1        default  ...         0.9       0.98  1.000000e-09          20
#
#    best_val_loss  best_perplexity  greedy_bleu  beam_bleu  total_time_min  \
# 0       3.959847        52.449279     3.704305   4.306684       21.843896
# 1       3.672899        39.365863     3.929490   4.703868       16.572420
#
#                                      checkpoint_path
# ...

# %%
import pandas as pd

history = pd.read_csv( "/content/drive/MyDrive/transformer-translation/experiments/d128_h8_enc4_dec4_ff512_bs32_lr0.001initxavier_history.csv"
)

history
# Out:
#    epoch  train_loss  val_loss   perplexity  epoch_time_min
# 0      1    6.237672  7.057453  1161.482848        1.553419
# 1      2    6.130836  7.488578  1787.508547        1.553361
# 2      3    6.104022  7.343563  1546.211663        1.556469
# 3      4    6.092220  7.583595  1965.682979        1.552653
# 4      5    6.078740  7.802510  2446.735223        1.556901
# 5      6    6.070748  8.199196  3638.022978        1.558929
# 6      7    6.067168  8.348537  4223.997005        1.563685
# 7      8    6.043494  8.592169  5389.288673        1.561409
# 8      9    6.011452  8.161287  3502.692072        1.546956
# 9     10    6.005712  8.182855  3579.059663        1.561419
