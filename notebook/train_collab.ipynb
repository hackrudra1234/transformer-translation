# %%
import torch

print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: False

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'sample_data']

# %%
# !git clone https://github.com/hackrudra1234/transformer-translation.git
# Out:
# Cloning into 'transformer-translation'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 45 (delta 6), reused 45 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (45/45), 214.32 KiB | 6.12 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/hackrudra1234/transformer-translation.git
# Out:
# fatal: destination path 'transformer-translation' already exists and is not an empty directory.

# %%
# %cd transformer-translation
# Out:
# /content/transformer-translation

# %%
# !ls
# Out:
# config.py  inference	      main_train.py  notebook	     training
# data	   main_inference.py  model	     pyproject.toml  uv.lock

# %%
# %pip install -q datasets sacrebleu tqdm pandas matplotlib
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 105.2 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.6/129.6 kB 13.9 MB/s eta 0:00:00

# %%
from model.transformer import Transformer
from data.data_utils import build_vocab, create_collate_fn
from inference.translate import translate_sentence

print("All project imports successful")
# Out:
# All project imports successful

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 371 bytes | 371.00 KiB/s, done.
# From https://github.com/hackrudra1234/transformer-translation
#    2f8d83d..da54ab1  main       -> origin/main
# Updating 2f8d83d..da54ab1
# Fast-forward
#  data/data_utils.py | 1 +
#  1 file changed, 1 insertion(+)

# %%
# !python main_train.py
# Out:
# Device: cpu
# ...
# Total examples: 51467
# Training examples: 46320
# Validation examples: 5147
# German vocab: 26953
# English vocab: 17627
# Model parameters: 9364059
# /usr/local/lib/python3.13/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Traceback (most recent call last):
#   File "/content/transformer-translation/main_train.py", line 312, in <module>
#     main()
#     ~~~~^^
#   File "/content/transformer-translation/main_train.py", line 215, in main
#     train_loss = train_one_epoch(
#         model,
#     ...<3 lines>...
#         device
#     )
#   File "/content/transformer-translation/training/train.py", line 78, in train_one_epoch
#     loss.backward()
#     ~~~~~~~~~~~~~^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/_tensor.py", line 625, in backward
#     torch.autograd.backward(
# ...

# %%
import torch

print("CUDA:", torch.cuda.is_available())

try:
    import torch_xla
    import torch_xla.core.xla_model as xm

    device = xm.xla_device()
    print("XLA device:", device)

except Exception as e:
    print("XLA error:", e)
# Out:
# CUDA: False
# /tmp/ipykernel_1831/483906953.py:9: DeprecationWarning: Use torch_xla.device instead
#   device = xm.xla_device()
# XLA device: xla:0

# %%
# !nvidia-smi
