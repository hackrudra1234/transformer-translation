# %%
# !git pull
# Out:
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 7 (delta 2), reused 7 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (7/7), 4.91 KiB | 2.45 MiB/s, done.
# From https://github.com/hackrudra1234/transformer-translation
#    520d829..47941bf  main       -> origin/main
# Updating 520d829..47941bf
# Fast-forward
#  config.py               |  27 +-
#  experiments/logger.py   | 120 +++++++
#  experiments/plotting.py | 127 ++++++++
#  main_train.py           | 829 +++++++++++++++++++++++++++++++++++++++++-------
#  4 files changed, 983 insertions(+), 120 deletions(-)
#  create mode 100644 experiments/logger.py
#  create mode 100644 experiments/plotting.py

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !python main_train.py
# Out:
# ...
# DEVICE INFORMATION
# ...
# Device: cuda
# GPU: Tesla T4
# GPU Memory: 14.56 GB
#
# ...
# EXPERIMENT
# ...
# Experiment name: d128_h4_enc3_dec3_ff512_bs32_lr0.001
# Checkpoint: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h4_enc3_dec3_ff512_bs32_lr0.001.pt
# Experiment directory: /content/drive/MyDrive/transformer-translation/experiments
# Plot directory: /content/drive/MyDrive/transformer-translation/plots
#
# ...
# LOADING DATASET
# ...
# Total examples: 51467
# Training examples: 46320
# Validation examples: 5147
#
# ...
# BUILDING VOCABULARY
# ...
# German vocabulary: 26953
# English vocabulary: 17627
# Training batches: 1448
# Validation batches: 161
#
# ...
# CREATING TRANSFORMER
# ...
# Total parameters: 9,364,059
# Trainable parameters: 9,364,059
#
# ...
# MODEL CONFIGURATION
# ...
# D_MODEL: 128
# HEADS: 4
# D_FF: 512
# ENCODER LAYERS: 3
# DECODER LAYERS: 3
# DROPOUT: 0.1
# BATCH SIZE: 32
# LEARNING RATE: 0.001
# EPOCHS: 10
#
# ...
# STARTING TRAINING
# ...
