# %%
# %cd /content

# %%
# !git clone https://github.com/hackrudra1234/transformer-translation.git

# %%
# %cd transformer-translation

# %%
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 5 (delta 2), reused 5 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 3.02 KiB | 1.51 MiB/s, done.
# From https://github.com/hackrudra1234/transformer-translation
#    e172540..3e25ee3  main       -> origin/main
# Updating e172540..3e25ee3
# Fast-forward
#  config.py                   |   2 +-
#  notebook/train_collab.ipynb | 327 +++++++++++++++++++++++++++-----------------
#  2 files changed, 206 insertions(+), 123 deletions(-)

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !python main_train.py
# Out:
# ======================================================================
# DEVICE INFORMATION
# ======================================================================
# Device: cuda
# GPU: Tesla T4
# GPU Memory: 14.56 GB
#
# ======================================================================
# EXPERIMENT
# ======================================================================
# Experiment name: d128_h4_enc3_dec3_ff512_bs32_lr0.001
# Checkpoint path: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h4_enc3_dec3_ff512_bs32_lr0.001.pt
# Experiment directory: /content/drive/MyDrive/transformer-translation/experiments
# Plot directory: /content/drive/MyDrive/transformer-translation/plots
#
# ======================================================================
# LOADING DATASET
# ======================================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Total examples: 51467
# Training examples: 46320
# Validation examples: 5147
#
# ======================================================================
# BUILDING VOCABULARY
# ======================================================================
# German vocab: 26953
# English vocab: 17627
# Training batches: 1448
# Validation batches: 161
#
# ======================================================================
# CREATING TRANSFORMER
# ======================================================================
# Total parameters: 9,364,059
# Trainable parameters: 9,364,059
#
# ======================================================================
# MODEL CONFIGURATION
# ======================================================================
# D_MODEL: 128
# NUM_HEADS: 4
# D_FF: 512
# ENCODER LAYERS: 3
# DECODER LAYERS: 3
# DROPOUT: 0.1
# BATCH SIZE: 32
# LEARNING RATE: 0.001
# EPOCHS: 10
# BLEU MAX EXAMPLES: 100
# BEAM SIZE: 4
# LENGTH PENALTY: 0.6
#
# ======================================================================
# STARTING TRAINING
# ======================================================================
# Epoch 01/10 | Train Loss: 5.0722 | Val Loss: 4.5531 | PPL: 94.93 | Time: 1.14 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h4_enc3_dec3_ff512_bs32_lr0.001.pt
# Epoch 02/10 | Train Loss: 4.4667 | Val Loss: 4.3115 | PPL: 74.55 | Time: 1.19 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h4_enc3_dec3_ff512_bs32_lr0.001.pt
# Epoch 03/10 | Train Loss: 4.2095 | Val Loss: 4.1647 | PPL: 64.37 | Time: 1.19 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h4_enc3_dec3_ff512_bs32_lr0.001.pt
# Epoch 04/10 | Train Loss: 4.0257 | Val Loss: 4.0902 | PPL: 59.75 | Time: 1.22 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h4_enc3_dec3_ff512_bs32_lr0.001.pt
# Epoch 05/10 | Train Loss: 3.8841 | Val Loss: 4.0268 | PPL: 56.08 | Time: 1.23 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h4_enc3_dec3_ff512_bs32_lr0.001.pt
# Epoch 06/10 | Train Loss: 3.7683 | Val Loss: 3.9848 | PPL: 53.77 | Time: 1.20 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h4_enc3_dec3_ff512_bs32_lr0.001.pt
# Epoch 07/10 | Train Loss: 3.6746 | Val Loss: 3.9759 | PPL: 53.30 | Time: 1.22 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h4_enc3_dec3_ff512_bs32_lr0.001.pt
# Epoch 08/10 | Train Loss: 3.5895 | Val Loss: 3.9453 | PPL: 51.69 | Time: 1.20 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h4_enc3_dec3_ff512_bs32_lr0.001.pt
# Epoch 09/10 | Train Loss: 3.5188 | Val Loss: 3.9374 | PPL: 51.29 | Time: 1.19 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h4_enc3_dec3_ff512_bs32_lr0.001.pt
# Epoch 10/10 | Train Loss: 3.4548 | Val Loss: 3.9224 | PPL: 50.52 | Time: 1.19 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h4_enc3_dec3_ff512_bs32_lr0.001.pt
#
# ======================================================================
# LOADING BEST MODEL
# ======================================================================
# Loaded best model from epoch: 10
#
# ======================================================================
# GREEDY BLEU
# ======================================================================
# Greedy BLEU: 2.55
# Greedy BLEU time: 0.26 min
#
# ======================================================================
# BEAM BLEU
# ======================================================================
# Beam BLEU: 2.79
# Beam BLEU time: 0.92 min
#
# ======================================================================
# GENERATING PLOTS
# ======================================================================
#
# ======================================================================
# EXPERIMENT COMPLETE
# ======================================================================
# Experiment: d128_h4_enc3_dec3_ff512_bs32_lr0.001
# Best epoch: 10
# Best validation loss: 3.9224
# Best perplexity: 50.52
# Greedy BLEU: 2.55
# Beam BLEU: 2.79
# Training time: 12.04 minutes
# Greedy BLEU time: 0.26 minutes
# Beam BLEU time: 0.92 minutes
# Peak GPU memory: 6.07 GB
#
# Checkpoint:
# /content/drive/MyDrive/transformer-translation/checkpoints/d128_h4_enc3_dec3_ff512_bs32_lr0.001.pt
#
# History:
# /content/drive/MyDrive/transformer-translation/experiments/d128_h4_enc3_dec3_ff512_bs32_lr0.001_history.csv
#
# Results:
# /content/drive/MyDrive/transformer-translation/experiments/results.csv
#
# Loss plot:
# /content/drive/MyDrive/transformer-translation/plots/d128_h4_enc3_dec3_ff512_bs32_lr0.001_loss.png
#
# Perplexity plot:
# /content/drive/MyDrive/transformer-translation/plots/d128_h4_enc3_dec3_ff512_bs32_lr0.001_perplexity.png
#
# Epoch-time plot:
# /content/drive/MyDrive/transformer-translation/plots/d128_h4_enc3_dec3_ff512_bs32_lr0.001_time.png

# %%
import pandas as pd

results_path = (
    "/content/drive/MyDrive/"
    "transformer-translation/experiments/"
    "results.csv"
)

results = pd.read_csv(results_path)

results
# Out:
#                              experiment  d_model  num_heads  d_ff  \
# 0  d128_h4_enc3_dec3_ff512_bs32_lr0.001      128          4   512
# 1  d128_h4_enc3_dec3_ff512_bs32_lr0.001      128          4   512
#
#    encoder_layers  decoder_layers  dropout  learning_rate  batch_size  \
# 0               3               3      0.1          0.001          32
# 1               3               3      0.1          0.001          32
#
#    best_epoch  best_val_loss  best_perplexity  greedy_bleu  beam_bleu  \
# 0          10       3.922425        50.522839          NaN        NaN
# 1          10       3.922425        50.522839     2.550098   2.785348
#
#    total_time_min                                    checkpoint_path
# 0       11.706865  /content/drive/MyDrive/transformer-translation...
# 1       12.039635  /content/drive/MyDrive/transformer-translation...
