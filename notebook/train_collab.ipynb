# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/hackrudra1234/transformer-translation.git
# Out:
# Cloning into 'transformer-translation'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 74 (delta 21), reused 66 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (74/74), 228.90 KiB | 1.67 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
# %cd transformer-translation
# Out:
# /content/transformer-translation

# %%
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 3), reused 5 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 2.04 KiB | 2.04 MiB/s, done.
# From https://github.com/hackrudra1234/transformer-translation
#    72f9ba4..2c3813b  main       -> origin/main
# Updating 72f9ba4..2c3813b
# Fast-forward
#  config.py                   |   4 +-
#  notebook/train_collab.ipynb | 237 ++++++++++++++++++++++++++++++++------------
#  2 files changed, 175 insertions(+), 66 deletions(-)

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %pip install -q datasets sacrebleu tqdm pandas matplotlib
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.6/129.6 kB 15.5 MB/s eta 0:00:00

# %%
# !git log -1 --oneline
# Out:
# 3e25ee3 (HEAD -> main, origin/main, origin/HEAD) Adding bleu config

# %%
# !python main_train.py
# Out:
# ======================================================================
# DEVICE INFORMATION
# ======================================================================
# Device: cuda
# GPU: Tesla T4
# GPU Memory: 14.56 GB
#
# ======================================================================
# EXPERIMENT
# ======================================================================
# Experiment name: d128_h8_enc4_dec4_ff512_bs32_lr0.001
# Checkpoint path: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h8_enc4_dec4_ff512_bs32_lr0.001.pt
# Experiment directory: /content/drive/MyDrive/transformer-translation/experiments
# Plot directory: /content/drive/MyDrive/transformer-translation/plots
#
# ======================================================================
# LOADING DATASET
# ======================================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Total examples: 51467
# Training examples: 46320
# Validation examples: 5147
#
# ======================================================================
# BUILDING VOCABULARY
# ======================================================================
# German vocab: 26953
# English vocab: 17627
# Training batches: 1448
# Validation batches: 161
#
# ======================================================================
# CREATING TRANSFORMER
# ======================================================================
# Total parameters: 9,825,371
# Trainable parameters: 9,825,371
#
# ======================================================================
# MODEL CONFIGURATION
# ======================================================================
# D_MODEL: 128
# NUM_HEADS: 8
# D_FF: 512
# ENCODER LAYERS: 4
# DECODER LAYERS: 4
# DROPOUT: 0.1
# BATCH SIZE: 32
# LEARNING RATE: 0.001
# EPOCHS: 10
# BLEU MAX EXAMPLES: 100
# BEAM SIZE: 4
# LENGTH PENALTY: 0.6
#
# ======================================================================
# STARTING TRAINING
# ======================================================================
# Epoch 01/10 | Train Loss: 5.0519 | Val Loss: 4.5127 | PPL: 91.17 | Time: 1.52 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h8_enc4_dec4_ff512_bs32_lr0.001.pt
# Epoch 02/10 | Train Loss: 4.4188 | Val Loss: 4.2624 | PPL: 70.98 | Time: 1.52 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h8_enc4_dec4_ff512_bs32_lr0.001.pt
# Epoch 03/10 | Train Loss: 4.1513 | Val Loss: 4.0935 | PPL: 59.95 | Time: 1.55 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h8_enc4_dec4_ff512_bs32_lr0.001.pt
# Epoch 04/10 | Train Loss: 3.9584 | Val Loss: 4.0122 | PPL: 55.27 | Time: 1.58 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h8_enc4_dec4_ff512_bs32_lr0.001.pt
# Epoch 05/10 | Train Loss: 3.8075 | Val Loss: 3.9575 | PPL: 52.33 | Time: 1.58 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h8_enc4_dec4_ff512_bs32_lr0.001.pt
# Epoch 06/10 | Train Loss: 3.6883 | Val Loss: 3.9266 | PPL: 50.73 | Time: 1.58 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h8_enc4_dec4_ff512_bs32_lr0.001.pt
# Epoch 07/10 | Train Loss: 3.5881 | Val Loss: 3.8995 | PPL: 49.38 | Time: 1.60 min
# Best model saved: /content/drive/MyDrive/transformer-translation/checkpoints/d128_h8_enc4_dec4_ff512_bs32_lr0.001.pt

# %%
import pandas as pd

results_path = (
    "/content/drive/MyDrive/"
    "transformer-translation/experiments/"
    "results.csv"
)

results = pd.read_csv(results_path)

results
# Out:
#                              experiment  d_model  num_heads  d_ff  \
# 0  d128_h4_enc3_dec3_ff512_bs32_lr0.001      128          4   512
# 1  d128_h4_enc3_dec3_ff512_bs32_lr0.001      128          4   512
# 2  d128_h8_enc3_dec3_ff512_bs32_lr0.001      128          8   512
#
#    encoder_layers  decoder_layers  dropout  learning_rate  batch_size  \
# 0               3               3      0.1          0.001          32
# 1               3               3      0.1          0.001          32
# 2               3               3      0.1          0.001          32
#
#    best_epoch  best_val_loss  best_perplexity  greedy_bleu  beam_bleu  \
# 0          10       3.922425        50.522839          NaN        NaN
# 1          10       3.922425        50.522839     2.550098   2.785348
# 2          10       3.914647        50.131387     2.935859   2.997479
#
#    total_time_min                                    checkpoint_path
# 0       11.706865  /content/drive/MyDrive/transformer-translation...
# 1       12.039635  /content/drive/MyDrive/transformer-translation...
# 2       12.961591  /content/drive/MyDrive/transformer-translation...
